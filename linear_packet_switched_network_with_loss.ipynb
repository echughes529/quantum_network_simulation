# %%
pip install simpy networkx
# Out:
# Collecting simpy
#   Downloading simpy-4.1.1-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.3)
# Downloading simpy-4.1.1-py3-none-any.whl (27 kB)
# Installing collected packages: simpy
# Successfully installed simpy-4.1.1

# %%
import simpy
import networkx as nx
import random

# Define a frame class to represent the frames being transferred in the network
class Frame:
    storage_time_limit = 10  # Maximum allowed storage time

    def __init__(self, env, source, destination, frame_id, probability):
        self.env = env  # Simulation environment
        self.source = source  # Source node of the frame
        self.destination = destination  # Destination node of the frame
        self.creation_time = env.now  # Timestamp of frame creation
        self.status = 'in transit' if random.random() < probability else 'discarded'  # Initial status
        self.path_traveled = [source]  # Path the frame has traveled
        self.frame_id = frame_id  # Unique identifier for the frame
        self.time_in_storage = 0  # Time spent in storage
        self.queue_entry_time = None  # Time when the frame is added to the queue
        self.guard_time = 3  # Guard time for frame integrity
        self.payload_time = 1
        self.temporal_frame_length = self.guard_time + self.payload_time  # Length of the frame in time units

    def update_frame_from_processing(self, pretransmission_delay, transmission_delay):
        # checking for invalid times
        if pretransmission_delay < 0 or self.guard_time < 0:
            raise ValueError("Invalid time value")

        # if the guard time is larger then it is reduced, no time in storage
        elif self.guard_time >= pretransmission_delay:
            self.guard_time -= pretransmission_delay
            self.temporal_frame_length -= pretransmission_delay

        # if the guard time is 0 then the frame is in storage the whole time
        # tramsission delay is halfed bc its the avg time part of the payload will spend in storage
        elif self.guard_time == 0:
            self.time_in_storage += (pretransmission_delay + transmission_delay / 2)

        # if the time delay is less then the guard time then the guard time
        # becomes zero and the packet is in storage after the guard time is used up
        elif self.guard_time < pretransmission_delay:
            self.temporal_frame_length -= self.guard_time
            self.time_in_storage += (pretransmission_delay - self.guard_time + transmission_delay / 2)
            self.guard_time = 0

        # checking if storage time limit has been reached
        if self.time_in_storage > Frame.storage_time_limit:
            self.status = 'discarded'

class NetworkNode:
    header_processing = 0

    def __init__(self, env, name, node_type, k=2):
        self.env = env  # Simulation environment
        self.name = name  # Name of the node
        self.node_type = node_type  # Type of node: 'sender', 'router', or 'receiver'
        self.queue = simpy.Store(env)  # Queue to store frames
        self.resource = simpy.Resource(env, capacity=k)  # Resource to handle k simultaneous processes

    def process_frames(self):
        while True:
            frame = yield self.queue.get()  # Get the next frame from the queue
            with self.resource.request() as request:
                yield request  # Wait until the resource is available

                queue_exit_time = self.env.now  # Record the time when the frame is retrieved from the queue
                time_in_queue = queue_exit_time - frame.queue_entry_time  # Calculate time spent in the queue
                print(f"Time {self.env.now}: Frame {frame.frame_id} spent {time_in_queue} time units in queue at {self.name}")

                if frame.status == 'discarded':
                    print(f"Time {self.env.now}: Frame {frame.frame_id} discarded at {self.name}")
                    continue  # Skip further processing if frame is discarded

                if self.node_type in ['router', 'receiver']:
                    # Simulate header processing delay for routers and receivers
                    yield self.env.timeout(NetworkNode.header_processing)

                    # update the frame with the total delay time at this node
                    total_preprocessing_delay = NetworkNode.header_processing + time_in_queue
                    transmission_delay = frame.temporal_frame_length

                    yield self.env.timeout(transmission_delay)
                    frame.update_frame_from_processing(total_preprocessing_delay, transmission_delay)

                    if frame.status == 'discarded':
                        print(f"Time {self.env.now}: Frame {frame.frame_id} discarded at {self.name}")
                        continue  # Skip further processing if frame is discarded

                if self.name != frame.destination:
                    # If the current node is not the destination, forward the frame
                    self.env.process(route_frame(self.env, frame, network, self))
                else:
                    # If the current node is the destination, deliver the frame
                    frame.status = 'arrived'
                    print(f"Time {self.env.now}: Frame {frame.frame_id} delivered at {self.name}, from {frame.source} to {frame.destination}")

    def put_frame_in_queue(self, frame):
        frame.queue_entry_time = self.env.now  # Record the time when the frame is added to the queue
        self.queue.put(frame)

# Define a function to generate frames at a given source node
def generate_frames(env, source_node, destination, interval, max_packets, probability):
    packet_count = 0  # Counter for the number of packets generated
    while packet_count < max_packets:
        yield env.timeout(interval)  # Wait for the next frame generation interval
        # Create a new frame with example attributes
        frame = Frame(env, source_node.name, destination, packet_count + 1, probability)
        source_node.put_frame_in_queue(frame)  # Put the frame in the source node's queue using the correct method
        print(f"\nTime {env.now}: Frame {frame.frame_id} created at {source_node.name}, destined for {destination}")
        frames.append(frame)  # Collect the frame for visualization
        packet_count += 1  # Increment the packet counter

def route_frame(env, frame, network, current_node):
    # Calculate the shortest path from the current node to the destination
    all_paths = list(nx.all_shortest_paths(network, source=current_node.name, target=frame.destination, weight='weight'))
    path = random.choice(all_paths)

    # Determine the next hop in the path
    next_hop = path[1]
    # Get the next node object from the dictionary
    next_node = node_dict[next_hop]

    yield env.timeout(0)

    frame.path_traveled.append(next_hop)  # Record the path traveled
    print(f"\nTime {env.now}: Frame {frame.frame_id} forwarded from {current_node.name} to {next_hop}")
    # Put the frame in the next node's queue
    next_node.put_frame_in_queue(frame)

def create_linear_graph(network, num_nodes):
    nodes = []
    for i in range(num_nodes):
        node = f'Node_{i}'
        nodes.append(node)
        network.add_node(node)
        # Connect each node to the next one
        if i > 0:
            network.add_edge(nodes[i - 1], node, weight=1)
            network.add_edge(node, nodes[i - 1], weight=1)
    return nodes

def initialize_simulation(num_nodes, sender, receiver):
    """
    num_nodes=int
    sender = int, index of sender node
    receiver = int, index of receiver node
    """
    global env, network, node_dict, frames
    env = simpy.Environment()
    network = nx.Graph()
    frames = []

    # Create a linear graph of nodes
    nodes = create_linear_graph(network, num_nodes)

    # Define node types (for simplicity, all nodes are routers except the sender and receiver)
    node_types = {}
    for i in range(num_nodes):
        if i == sender:
            node_types[f'Node_{i}'] = 'sender'
        elif i == receiver:
            node_types[f'Node_{i}'] = 'receiver'
        else:
            node_types[f'Node_{i}'] = 'router'

    # Create network node objects and store them in a dictionary
    node_dict = {name: NetworkNode(env, name, node_types[name], k=1) for name in nodes}

def run_simulation(max_packets, interval, num_nodes, sender, receiver, probability, max_retries=5):
    initialize_simulation(num_nodes, sender, receiver)

    # Start the frame generation process at the sender node, creating frames destined for the receiver node
    env.process(generate_frames(env, node_dict[f'Node_{sender}'], f'Node_{receiver}', interval=interval, max_packets=max_packets, probability=probability))

    # Start the frame processing process for each node in the network
    for node in node_dict.values():
        env.process(node.process_frames())

    # Run the simulation until all packets are generated and processed
    while len(frames) < max_packets or any(frame.status == 'in transit' for frame in frames):
        env.step()

    retries = 0
    # Resend discarded frames that did not arrive at the destination probabilistically
    while retries < max_retries:
        discarded_frames = [frame for frame in frames if frame.status == 'discarded' or frame.path_traveled[-1] != f'Node_{receiver}']

        if not discarded_frames:
            break  # Exit the loop if no frames need to be resent

        print('\n')
        for frame in discarded_frames:
            # reset parameters
            frame.creation_time = frame.env.now
            frame.status = 'in transit' if random.random() < probability else 'discarded'
            frame.path_traveled = [frame.source]  # Reset path traveled
            frame.time_in_storage = 0
            frame.guard_time = 3
            frame.temporal_frame_length = frame.guard_time + frame.payload_time

            print(f"Retrying frame {frame.frame_id}, new status: {frame.status}")
            node_dict[f'Node_{sender}'].put_frame_in_queue(frame)  # Resend frame from the sender node

        print('\n')
        # Run the simulation again for the resent frames
        while any(frame.status == 'in transit' for frame in frames):
            env.step()

        retries += 1

    # Count packets received and not received
    received_count = sum(1 for frame in frames if frame.status == 'arrived')
    not_received_count = len(frames) - received_count
    discarded_frame_ids = [frame.frame_id for frame in frames if frame.status == 'discarded']

    print(f"\nSimulation completed. Packets received: {received_count}, Packets not received: {not_received_count}")
    print(f"Retries: {retries}")
    print(f"Discarded frames: {discarded_frame_ids}")

# Main code to run the simulation

max_packets = 100  # Number of packets to generate and process
interval = 5  # Time interval between packet generations
num_nodes = 3  # Number of nodes in the linear graph
sender = 0  # Index of the sender node
receiver = 2  # Index of the receiver node
probability = 0.9  # Probability of a packet being 'in transit'

run_simulation(max_packets, interval, num_nodes, sender, receiver, probability)
# Out:
# Time 5: Frame 1 created at Node_0, destined for Node_2
# Time 5: Frame 1 spent 0 time units in queue at Node_0
#
# Time 5: Frame 1 forwarded from Node_0 to Node_1
# Time 5: Frame 1 spent 0 time units in queue at Node_1
#
# Time 9: Frame 1 forwarded from Node_1 to Node_2
# Time 9: Frame 1 spent 0 time units in queue at Node_2
#
# Time 10: Frame 2 created at Node_0, destined for Node_2
# Time 10: Frame 2 spent 0 time units in queue at Node_0
#
# Time 10: Frame 2 forwarded from Node_0 to Node_1
# Time 10: Frame 2 spent 0 time units in queue at Node_1
# Time 13: Frame 1 delivered at Node_2, from Node_0 to Node_2
#
# Time 14: Frame 2 forwarded from Node_1 to Node_2
# Time 14: Frame 2 spent 0 time units in queue at Node_2
#
# Time 15: Frame 3 created at Node_0, destined for Node_2
# Time 15: Frame 3 spent 0 time units in queue at Node_0
#
# Time 15: Frame 3 forwarded from Node_0 to Node_1
# Time 15: Frame 3 spent 0 time units in queue at Node_1
# Time 18: Frame 2 delivered at Node_2, from Node_0 to Node_2
#
# Time 19: Frame 3 forwarded from Node_1 to Node_2
# Time 19: Frame 3 spent 0 time units in queue at Node_2
#
# Time 20: Frame 4 created at Node_0, destined for Node_2
# Time 20: Frame 4 spent 0 time units in queue at Node_0
#
# Time 20: Frame 4 forwarded from Node_0 to Node_1
# Time 20: Frame 4 spent 0 time units in queue at Node_1
# Time 23: Frame 3 delivered at Node_2, from Node_0 to Node_2
#
# Time 24: Frame 4 forwarded from Node_1 to Node_2
# Time 24: Frame 4 spent 0 time units in queue at Node_2
#
# Time 25: Frame 5 created at Node_0, destined for Node_2
# Time 25: Frame 5 spent 0 time units in queue at Node_0
# Time 25: Frame 5 discarded at Node_0
# Time 28: Frame 4 delivered at Node_2, from Node_0 to Node_2
#
# Time 30: Frame 6 created at Node_0, destined for Node_2
# Time 30: Frame 6 spent 0 time units in queue at Node_0
#
# Time 30: Frame 6 forwarded from Node_0 to Node_1
# Time 30: Frame 6 spent 0 time units in queue at Node_1
#
# Time 34: Frame 6 forwarded from Node_1 to Node_2
# Time 34: Frame 6 spent 0 time units in queue at Node_2
#
# Time 35: Frame 7 created at Node_0, destined for Node_2
# Time 35: Frame 7 spent 0 time units in queue at Node_0
#
# Time 35: Frame 7 forwarded from Node_0 to Node_1
# Time 35: Frame 7 spent 0 time units in queue at Node_1
# Time 38: Frame 6 delivered at Node_2, from Node_0 to Node_2
#
# Time 39: Frame 7 forwarded from Node_1 to Node_2
# Time 39: Frame 7 spent 0 time units in queue at Node_2
#
# Time 40: Frame 8 created at Node_0, destined for Node_2
# Time 40: Frame 8 spent 0 time units in queue at Node_0
#
# Time 40: Frame 8 forwarded from Node_0 to Node_1
# Time 40: Frame 8 spent 0 time units in queue at Node_1
# Time 43: Frame 7 delivered at Node_2, from Node_0 to Node_2
#
# Time 44: Frame 8 forwarded from Node_1 to Node_2
# Time 44: Frame 8 spent 0 time units in queue at Node_2
#
# Time 45: Frame 9 created at Node_0, destined for Node_2
# Time 45: Frame 9 spent 0 time units in queue at Node_0
#
# Time 45: Frame 9 forwarded from Node_0 to Node_1
# Time 45: Frame 9 spent 0 time units in queue at Node_1
# Time 48: Frame 8 delivered at Node_2, from Node_0 to Node_2
#
# Time 49: Frame 9 forwarded from Node_1 to Node_2
# Time 49: Frame 9 spent 0 time units in queue at Node_2
#
# Time 50: Frame 10 created at Node_0, destined for Node_2
# Time 50: Frame 10 spent 0 time units in queue at Node_0
#
# Time 50: Frame 10 forwarded from Node_0 to Node_1
# Time 50: Frame 10 spent 0 time units in queue at Node_1
# Time 53: Frame 9 delivered at Node_2, from Node_0 to Node_2
#
# Time 54: Frame 10 forwarded from Node_1 to Node_2
# Time 54: Frame 10 spent 0 time units in queue at Node_2
#
# Time 55: Frame 11 created at Node_0, destined for Node_2
# Time 55: Frame 11 spent 0 time units in queue at Node_0
#
# Time 55: Frame 11 forwarded from Node_0 to Node_1
# Time 55: Frame 11 spent 0 time units in queue at Node_1
# Time 58: Frame 10 delivered at Node_2, from Node_0 to Node_2
#
# Time 59: Frame 11 forwarded from Node_1 to Node_2
# Time 59: Frame 11 spent 0 time units in queue at Node_2
#
# Time 60: Frame 12 created at Node_0, destined for Node_2
# Time 60: Frame 12 spent 0 time units in queue at Node_0
# Time 60: Frame 12 discarded at Node_0
# Time 63: Frame 11 delivered at Node_2, from Node_0 to Node_2
#
# Time 65: Frame 13 created at Node_0, destined for Node_2
# Time 65: Frame 13 spent 0 time units in queue at Node_0
#
# Time 65: Frame 13 forwarded from Node_0 to Node_1
# Time 65: Frame 13 spent 0 time units in queue at Node_1
#
# Time 69: Frame 13 forwarded from Node_1 to Node_2
# Time 69: Frame 13 spent 0 time units in queue at Node_2
#
# Time 70: Frame 14 created at Node_0, destined for Node_2
# Time 70: Frame 14 spent 0 time units in queue at Node_0
#
# Time 70: Frame 14 forwarded from Node_0 to Node_1
# Time 70: Frame 14 spent 0 time units in queue at Node_1
# Time 73: Frame 13 delivered at Node_2, from Node_0 to Node_2
#
# Time 74: Frame 14 forwarded from Node_1 to Node_2
# Time 74: Frame 14 spent 0 time units in queue at Node_2
#
# Time 75: Frame 15 created at Node_0, destined for Node_2
# Time 75: Frame 15 spent 0 time units in queue at Node_0
#
# Time 75: Frame 15 forwarded from Node_0 to Node_1
# Time 75: Frame 15 spent 0 time units in queue at Node_1
# Time 78: Frame 14 delivered at Node_2, from Node_0 to Node_2
#
# Time 79: Frame 15 forwarded from Node_1 to Node_2
# Time 79: Frame 15 spent 0 time units in queue at Node_2
#
# Time 80: Frame 16 created at Node_0, destined for Node_2
# Time 80: Frame 16 spent 0 time units in queue at Node_0
# Time 80: Frame 16 discarded at Node_0
# Time 83: Frame 15 delivered at Node_2, from Node_0 to Node_2
#
# Time 85: Frame 17 created at Node_0, destined for Node_2
# Time 85: Frame 17 spent 0 time units in queue at Node_0
#
# Time 85: Frame 17 forwarded from Node_0 to Node_1
# Time 85: Frame 17 spent 0 time units in queue at Node_1
#
# Time 89: Frame 17 forwarded from Node_1 to Node_2
# Time 89: Frame 17 spent 0 time units in queue at Node_2
#
# Time 90: Frame 18 created at Node_0, destined for Node_2
# Time 90: Frame 18 spent 0 time units in queue at Node_0
#
# Time 90: Frame 18 forwarded from Node_0 to Node_1
# Time 90: Frame 18 spent 0 time units in queue at Node_1
# Time 93: Frame 17 delivered at Node_2, from Node_0 to Node_2
#
# Time 94: Frame 18 forwarded from Node_1 to Node_2
# Time 94: Frame 18 spent 0 time units in queue at Node_2
#
# Time 95: Frame 19 created at Node_0, destined for Node_2
# Time 95: Frame 19 spent 0 time units in queue at Node_0
#
# Time 95: Frame 19 forwarded from Node_0 to Node_1
# Time 95: Frame 19 spent 0 time units in queue at Node_1
# Time 98: Frame 18 delivered at Node_2, from Node_0 to Node_2
#
# Time 99: Frame 19 forwarded from Node_1 to Node_2
# Time 99: Frame 19 spent 0 time units in queue at Node_2
#
# Time 100: Frame 20 created at Node_0, destined for Node_2
# Time 100: Frame 20 spent 0 time units in queue at Node_0
#
# Time 100: Frame 20 forwarded from Node_0 to Node_1
# Time 100: Frame 20 spent 0 time units in queue at Node_1
# Time 103: Frame 19 delivered at Node_2, from Node_0 to Node_2
#
# Time 104: Frame 20 forwarded from Node_1 to Node_2
# Time 104: Frame 20 spent 0 time units in queue at Node_2
#
# Time 105: Frame 21 created at Node_0, destined for Node_2
# Time 105: Frame 21 spent 0 time units in queue at Node_0
#
# Time 105: Frame 21 forwarded from Node_0 to Node_1
# Time 105: Frame 21 spent 0 time units in queue at Node_1
# Time 108: Frame 20 delivered at Node_2, from Node_0 to Node_2
#
# Time 109: Frame 21 forwarded from Node_1 to Node_2
# Time 109: Frame 21 spent 0 time units in queue at Node_2
#
# Time 110: Frame 22 created at Node_0, destined for Node_2
# Time 110: Frame 22 spent 0 time units in queue at Node_0
#
# Time 110: Frame 22 forwarded from Node_0 to Node_1
# Time 110: Frame 22 spent 0 time units in queue at Node_1
# Time 113: Frame 21 delivered at Node_2, from Node_0 to Node_2
#
# Time 114: Frame 22 forwarded from Node_1 to Node_2
# Time 114: Frame 22 spent 0 time units in queue at Node_2
#
# Time 115: Frame 23 created at Node_0, destined for Node_2
# Time 115: Frame 23 spent 0 time units in queue at Node_0
#
# Time 115: Frame 23 forwarded from Node_0 to Node_1
# Time 115: Frame 23 spent 0 time units in queue at Node_1
# Time 118: Frame 22 delivered at Node_2, from Node_0 to Node_2
#
# Time 119: Frame 23 forwarded from Node_1 to Node_2
# Time 119: Frame 23 spent 0 time units in queue at Node_2
#
# Time 120: Frame 24 created at Node_0, destined for Node_2
# Time 120: Frame 24 spent 0 time units in queue at Node_0
#
# Time 120: Frame 24 forwarded from Node_0 to Node_1
# Time 120: Frame 24 spent 0 time units in queue at Node_1
# Time 123: Frame 23 delivered at Node_2, from Node_0 to Node_2
#
# Time 124: Frame 24 forwarded from Node_1 to Node_2
# Time 124: Frame 24 spent 0 time units in queue at Node_2
#
# Time 125: Frame 25 created at Node_0, destined for Node_2
# Time 125: Frame 25 spent 0 time units in queue at Node_0
# Time 125: Frame 25 discarded at Node_0
# Time 128: Frame 24 delivered at Node_2, from Node_0 to Node_2
#
# Time 130: Frame 26 created at Node_0, destined for Node_2
# Time 130: Frame 26 spent 0 time units in queue at Node_0
#
# Time 130: Frame 26 forwarded from Node_0 to Node_1
# Time 130: Frame 26 spent 0 time units in queue at Node_1
#
# Time 134: Frame 26 forwarded from Node_1 to Node_2
# Time 134: Frame 26 spent 0 time units in queue at Node_2
#
# Time 135: Frame 27 created at Node_0, destined for Node_2
# Time 135: Frame 27 spent 0 time units in queue at Node_0
#
# Time 135: Frame 27 forwarded from Node_0 to Node_1
# Time 135: Frame 27 spent 0 time units in queue at Node_1
# Time 138: Frame 26 delivered at Node_2, from Node_0 to Node_2
#
# Time 139: Frame 27 forwarded from Node_1 to Node_2
# Time 139: Frame 27 spent 0 time units in queue at Node_2
#
# Time 140: Frame 28 created at Node_0, destined for Node_2
# Time 140: Frame 28 spent 0 time units in queue at Node_0
#
# Time 140: Frame 28 forwarded from Node_0 to Node_1
# Time 140: Frame 28 spent 0 time units in queue at Node_1
# Time 143: Frame 27 delivered at Node_2, from Node_0 to Node_2
#
# Time 144: Frame 28 forwarded from Node_1 to Node_2
# Time 144: Frame 28 spent 0 time units in queue at Node_2
#
# Time 145: Frame 29 created at Node_0, destined for Node_2
# Time 145: Frame 29 spent 0 time units in queue at Node_0
#
# Time 145: Frame 29 forwarded from Node_0 to Node_1
# Time 145: Frame 29 spent 0 time units in queue at Node_1
# Time 148: Frame 28 delivered at Node_2, from Node_0 to Node_2
#
# Time 149: Frame 29 forwarded from Node_1 to Node_2
# Time 149: Frame 29 spent 0 time units in queue at Node_2
#
# Time 150: Frame 30 created at Node_0, destined for Node_2
# Time 150: Frame 30 spent 0 time units in queue at Node_0
#
# Time 150: Frame 30 forwarded from Node_0 to Node_1
# Time 150: Frame 30 spent 0 time units in queue at Node_1
# Time 153: Frame 29 delivered at Node_2, from Node_0 to Node_2
#
# Time 154: Frame 30 forwarded from Node_1 to Node_2
# Time 154: Frame 30 spent 0 time units in queue at Node_2
#
# Time 155: Frame 31 created at Node_0, destined for Node_2
# Time 155: Frame 31 spent 0 time units in queue at Node_0
#
# Time 155: Frame 31 forwarded from Node_0 to Node_1
# Time 155: Frame 31 spent 0 time units in queue at Node_1
# Time 158: Frame 30 delivered at Node_2, from Node_0 to Node_2
#
# Time 159: Frame 31 forwarded from Node_1 to Node_2
# Time 159: Frame 31 spent 0 time units in queue at Node_2
#
# Time 160: Frame 32 created at Node_0, destined for Node_2
# Time 160: Frame 32 spent 0 time units in queue at Node_0
#
# Time 160: Frame 32 forwarded from Node_0 to Node_1
# Time 160: Frame 32 spent 0 time units in queue at Node_1
# Time 163: Frame 31 delivered at Node_2, from Node_0 to Node_2
#
# Time 164: Frame 32 forwarded from Node_1 to Node_2
# Time 164: Frame 32 spent 0 time units in queue at Node_2
#
# Time 165: Frame 33 created at Node_0, destined for Node_2
# Time 165: Frame 33 spent 0 time units in queue at Node_0
#
# Time 165: Frame 33 forwarded from Node_0 to Node_1
# Time 165: Frame 33 spent 0 time units in queue at Node_1
# Time 168: Frame 32 delivered at Node_2, from Node_0 to Node_2
#
# Time 169: Frame 33 forwarded from Node_1 to Node_2
# Time 169: Frame 33 spent 0 time units in queue at Node_2
#
# Time 170: Frame 34 created at Node_0, destined for Node_2
# Time 170: Frame 34 spent 0 time units in queue at Node_0
#
# Time 170: Frame 34 forwarded from Node_0 to Node_1
# Time 170: Frame 34 spent 0 time units in queue at Node_1
# Time 173: Frame 33 delivered at Node_2, from Node_0 to Node_2
#
# Time 174: Frame 34 forwarded from Node_1 to Node_2
# Time 174: Frame 34 spent 0 time units in queue at Node_2
#
# Time 175: Frame 35 created at Node_0, destined for Node_2
# Time 175: Frame 35 spent 0 time units in queue at Node_0
#
# Time 175: Frame 35 forwarded from Node_0 to Node_1
# Time 175: Frame 35 spent 0 time units in queue at Node_1
# Time 178: Frame 34 delivered at Node_2, from Node_0 to Node_2
#
# Time 179: Frame 35 forwarded from Node_1 to Node_2
# Time 179: Frame 35 spent 0 time units in queue at Node_2
#
# Time 180: Frame 36 created at Node_0, destined for Node_2
# Time 180: Frame 36 spent 0 time units in queue at Node_0
#
# Time 180: Frame 36 forwarded from Node_0 to Node_1
# Time 180: Frame 36 spent 0 time units in queue at Node_1
# Time 183: Frame 35 delivered at Node_2, from Node_0 to Node_2
#
# Time 184: Frame 36 forwarded from Node_1 to Node_2
# Time 184: Frame 36 spent 0 time units in queue at Node_2
#
# Time 185: Frame 37 created at Node_0, destined for Node_2
# Time 185: Frame 37 spent 0 time units in queue at Node_0
#
# Time 185: Frame 37 forwarded from Node_0 to Node_1
# Time 185: Frame 37 spent 0 time units in queue at Node_1
# Time 188: Frame 36 delivered at Node_2, from Node_0 to Node_2
#
# Time 189: Frame 37 forwarded from Node_1 to Node_2
# Time 189: Frame 37 spent 0 time units in queue at Node_2
#
# Time 190: Frame 38 created at Node_0, destined for Node_2
# Time 190: Frame 38 spent 0 time units in queue at Node_0
#
# Time 190: Frame 38 forwarded from Node_0 to Node_1
# Time 190: Frame 38 spent 0 time units in queue at Node_1
# Time 193: Frame 37 delivered at Node_2, from Node_0 to Node_2
#
# Time 194: Frame 38 forwarded from Node_1 to Node_2
# Time 194: Frame 38 spent 0 time units in queue at Node_2
#
# Time 195: Frame 39 created at Node_0, destined for Node_2
# Time 195: Frame 39 spent 0 time units in queue at Node_0
#
# Time 195: Frame 39 forwarded from Node_0 to Node_1
# Time 195: Frame 39 spent 0 time units in queue at Node_1
# Time 198: Frame 38 delivered at Node_2, from Node_0 to Node_2
#
# Time 199: Frame 39 forwarded from Node_1 to Node_2
# Time 199: Frame 39 spent 0 time units in queue at Node_2
#
# Time 200: Frame 40 created at Node_0, destined for Node_2
# Time 200: Frame 40 spent 0 time units in queue at Node_0
#
# Time 200: Frame 40 forwarded from Node_0 to Node_1
# Time 200: Frame 40 spent 0 time units in queue at Node_1
# Time 203: Frame 39 delivered at Node_2, from Node_0 to Node_2
#
# Time 204: Frame 40 forwarded from Node_1 to Node_2
# Time 204: Frame 40 spent 0 time units in queue at Node_2
#
# Time 205: Frame 41 created at Node_0, destined for Node_2
# Time 205: Frame 41 spent 0 time units in queue at Node_0
# Time 205: Frame 41 discarded at Node_0
# Time 208: Frame 40 delivered at Node_2, from Node_0 to Node_2
#
# Time 210: Frame 42 created at Node_0, destined for Node_2
# Time 210: Frame 42 spent 0 time units in queue at Node_0
#
# Time 210: Frame 42 forwarded from Node_0 to Node_1
# Time 210: Frame 42 spent 0 time units in queue at Node_1
#
# Time 214: Frame 42 forwarded from Node_1 to Node_2
# Time 214: Frame 42 spent 0 time units in queue at Node_2
#
# Time 215: Frame 43 created at Node_0, destined for Node_2
# Time 215: Frame 43 spent 0 time units in queue at Node_0
#
# Time 215: Frame 43 forwarded from Node_0 to Node_1
# Time 215: Frame 43 spent 0 time units in queue at Node_1
# Time 218: Frame 42 delivered at Node_2, from Node_0 to Node_2
#
# Time 219: Frame 43 forwarded from Node_1 to Node_2
# Time 219: Frame 43 spent 0 time units in queue at Node_2
#
# Time 220: Frame 44 created at Node_0, destined for Node_2
# Time 220: Frame 44 spent 0 time units in queue at Node_0
#
# Time 220: Frame 44 forwarded from Node_0 to Node_1
# Time 220: Frame 44 spent 0 time units in queue at Node_1
# Time 223: Frame 43 delivered at Node_2, from Node_0 to Node_2
#
# Time 224: Frame 44 forwarded from Node_1 to Node_2
# Time 224: Frame 44 spent 0 time units in queue at Node_2
#
# Time 225: Frame 45 created at Node_0, destined for Node_2
# Time 225: Frame 45 spent 0 time units in queue at Node_0
#
# Time 225: Frame 45 forwarded from Node_0 to Node_1
# Time 225: Frame 45 spent 0 time units in queue at Node_1
# Time 228: Frame 44 delivered at Node_2, from Node_0 to Node_2
#
# Time 229: Frame 45 forwarded from Node_1 to Node_2
# Time 229: Frame 45 spent 0 time units in queue at Node_2
#
# Time 230: Frame 46 created at Node_0, destined for Node_2
# Time 230: Frame 46 spent 0 time units in queue at Node_0
#
# Time 230: Frame 46 forwarded from Node_0 to Node_1
# Time 230: Frame 46 spent 0 time units in queue at Node_1
# Time 233: Frame 45 delivered at Node_2, from Node_0 to Node_2
#
# Time 234: Frame 46 forwarded from Node_1 to Node_2
# Time 234: Frame 46 spent 0 time units in queue at Node_2
#
# Time 235: Frame 47 created at Node_0, destined for Node_2
# Time 235: Frame 47 spent 0 time units in queue at Node_0
# Time 235: Frame 47 discarded at Node_0
# Time 238: Frame 46 delivered at Node_2, from Node_0 to Node_2
#
# Time 240: Frame 48 created at Node_0, destined for Node_2
# Time 240: Frame 48 spent 0 time units in queue at Node_0
#
# Time 240: Frame 48 forwarded from Node_0 to Node_1
# Time 240: Frame 48 spent 0 time units in queue at Node_1
#
# Time 244: Frame 48 forwarded from Node_1 to Node_2
# Time 244: Frame 48 spent 0 time units in queue at Node_2
#
# Time 245: Frame 49 created at Node_0, destined for Node_2
# Time 245: Frame 49 spent 0 time units in queue at Node_0
#
# Time 245: Frame 49 forwarded from Node_0 to Node_1
# Time 245: Frame 49 spent 0 time units in queue at Node_1
# Time 248: Frame 48 delivered at Node_2, from Node_0 to Node_2
#
# Time 249: Frame 49 forwarded from Node_1 to Node_2
# Time 249: Frame 49 spent 0 time units in queue at Node_2
#
# Time 250: Frame 50 created at Node_0, destined for Node_2
# Time 250: Frame 50 spent 0 time units in queue at Node_0
#
# Time 250: Frame 50 forwarded from Node_0 to Node_1
# Time 250: Frame 50 spent 0 time units in queue at Node_1
# Time 253: Frame 49 delivered at Node_2, from Node_0 to Node_2
#
# Time 254: Frame 50 forwarded from Node_1 to Node_2
# Time 254: Frame 50 spent 0 time units in queue at Node_2
#
# Time 255: Frame 51 created at Node_0, destined for Node_2
# Time 255: Frame 51 spent 0 time units in queue at Node_0
#
# Time 255: Frame 51 forwarded from Node_0 to Node_1
# Time 255: Frame 51 spent 0 time units in queue at Node_1
# Time 258: Frame 50 delivered at Node_2, from Node_0 to Node_2
#
# Time 259: Frame 51 forwarded from Node_1 to Node_2
# Time 259: Frame 51 spent 0 time units in queue at Node_2
#
# Time 260: Frame 52 created at Node_0, destined for Node_2
# Time 260: Frame 52 spent 0 time units in queue at Node_0
# Time 260: Frame 52 discarded at Node_0
# Time 263: Frame 51 delivered at Node_2, from Node_0 to Node_2
#
# Time 265: Frame 53 created at Node_0, destined for Node_2
# Time 265: Frame 53 spent 0 time units in queue at Node_0
#
# Time 265: Frame 53 forwarded from Node_0 to Node_1
# Time 265: Frame 53 spent 0 time units in queue at Node_1
#
# Time 269: Frame 53 forwarded from Node_1 to Node_2
# Time 269: Frame 53 spent 0 time units in queue at Node_2
#
# Time 270: Frame 54 created at Node_0, destined for Node_2
# Time 270: Frame 54 spent 0 time units in queue at Node_0
#
# Time 270: Frame 54 forwarded from Node_0 to Node_1
# Time 270: Frame 54 spent 0 time units in queue at Node_1
# Time 273: Frame 53 delivered at Node_2, from Node_0 to Node_2
#
# Time 274: Frame 54 forwarded from Node_1 to Node_2
# Time 274: Frame 54 spent 0 time units in queue at Node_2
#
# Time 275: Frame 55 created at Node_0, destined for Node_2
# Time 275: Frame 55 spent 0 time units in queue at Node_0
# Time 275: Frame 55 discarded at Node_0
# Time 278: Frame 54 delivered at Node_2, from Node_0 to Node_2
#
# Time 280: Frame 56 created at Node_0, destined for Node_2
# Time 280: Frame 56 spent 0 time units in queue at Node_0
#
# Time 280: Frame 56 forwarded from Node_0 to Node_1
# Time 280: Frame 56 spent 0 time units in queue at Node_1
#
# Time 284: Frame 56 forwarded from Node_1 to Node_2
# Time 284: Frame 56 spent 0 time units in queue at Node_2
#
# Time 285: Frame 57 created at Node_0, destined for Node_2
# Time 285: Frame 57 spent 0 time units in queue at Node_0
#
# Time 285: Frame 57 forwarded from Node_0 to Node_1
# Time 285: Frame 57 spent 0 time units in queue at Node_1
# Time 288: Frame 56 delivered at Node_2, from Node_0 to Node_2
#
# Time 289: Frame 57 forwarded from Node_1 to Node_2
# Time 289: Frame 57 spent 0 time units in queue at Node_2
#
# Time 290: Frame 58 created at Node_0, destined for Node_2
# Time 290: Frame 58 spent 0 time units in queue at Node_0
#
# Time 290: Frame 58 forwarded from Node_0 to Node_1
# Time 290: Frame 58 spent 0 time units in queue at Node_1
# Time 293: Frame 57 delivered at Node_2, from Node_0 to Node_2
#
# Time 294: Frame 58 forwarded from Node_1 to Node_2
# Time 294: Frame 58 spent 0 time units in queue at Node_2
#
# Time 295: Frame 59 created at Node_0, destined for Node_2
# Time 295: Frame 59 spent 0 time units in queue at Node_0
#
# Time 295: Frame 59 forwarded from Node_0 to Node_1
# Time 295: Frame 59 spent 0 time units in queue at Node_1
# Time 298: Frame 58 delivered at Node_2, from Node_0 to Node_2
#
# Time 299: Frame 59 forwarded from Node_1 to Node_2
# Time 299: Frame 59 spent 0 time units in queue at Node_2
#
# Time 300: Frame 60 created at Node_0, destined for Node_2
# Time 300: Frame 60 spent 0 time units in queue at Node_0
#
# Time 300: Frame 60 forwarded from Node_0 to Node_1
# Time 300: Frame 60 spent 0 time units in queue at Node_1
# Time 303: Frame 59 delivered at Node_2, from Node_0 to Node_2
#
# Time 304: Frame 60 forwarded from Node_1 to Node_2
# Time 304: Frame 60 spent 0 time units in queue at Node_2
#
# Time 305: Frame 61 created at Node_0, destined for Node_2
# Time 305: Frame 61 spent 0 time units in queue at Node_0
#
# Time 305: Frame 61 forwarded from Node_0 to Node_1
# Time 305: Frame 61 spent 0 time units in queue at Node_1
# Time 308: Frame 60 delivered at Node_2, from Node_0 to Node_2
#
# Time 309: Frame 61 forwarded from Node_1 to Node_2
# Time 309: Frame 61 spent 0 time units in queue at Node_2
#
# Time 310: Frame 62 created at Node_0, destined for Node_2
# Time 310: Frame 62 spent 0 time units in queue at Node_0
#
# Time 310: Frame 62 forwarded from Node_0 to Node_1
# Time 310: Frame 62 spent 0 time units in queue at Node_1
# Time 313: Frame 61 delivered at Node_2, from Node_0 to Node_2
#
# Time 314: Frame 62 forwarded from Node_1 to Node_2
# Time 314: Frame 62 spent 0 time units in queue at Node_2
#
# Time 315: Frame 63 created at Node_0, destined for Node_2
# Time 315: Frame 63 spent 0 time units in queue at Node_0
# Time 315: Frame 63 discarded at Node_0
# Time 318: Frame 62 delivered at Node_2, from Node_0 to Node_2
#
# Time 320: Frame 64 created at Node_0, destined for Node_2
# Time 320: Frame 64 spent 0 time units in queue at Node_0
#
# Time 320: Frame 64 forwarded from Node_0 to Node_1
# Time 320: Frame 64 spent 0 time units in queue at Node_1
#
# Time 324: Frame 64 forwarded from Node_1 to Node_2
# Time 324: Frame 64 spent 0 time units in queue at Node_2
#
# Time 325: Frame 65 created at Node_0, destined for Node_2
# Time 325: Frame 65 spent 0 time units in queue at Node_0
#
# Time 325: Frame 65 forwarded from Node_0 to Node_1
# Time 325: Frame 65 spent 0 time units in queue at Node_1
# Time 328: Frame 64 delivered at Node_2, from Node_0 to Node_2
#
# Time 329: Frame 65 forwarded from Node_1 to Node_2
# Time 329: Frame 65 spent 0 time units in queue at Node_2
#
# Time 330: Frame 66 created at Node_0, destined for Node_2
# Time 330: Frame 66 spent 0 time units in queue at Node_0
#
# Time 330: Frame 66 forwarded from Node_0 to Node_1
# Time 330: Frame 66 spent 0 time units in queue at Node_1
# Time 333: Frame 65 delivered at Node_2, from Node_0 to Node_2
#
# Time 334: Frame 66 forwarded from Node_1 to Node_2
# Time 334: Frame 66 spent 0 time units in queue at Node_2
#
# Time 335: Frame 67 created at Node_0, destined for Node_2
# Time 335: Frame 67 spent 0 time units in queue at Node_0
# Time 335: Frame 67 discarded at Node_0
# Time 338: Frame 66 delivered at Node_2, from Node_0 to Node_2
#
# Time 340: Frame 68 created at Node_0, destined for Node_2
# Time 340: Frame 68 spent 0 time units in queue at Node_0
#
# Time 340: Frame 68 forwarded from Node_0 to Node_1
# Time 340: Frame 68 spent 0 time units in queue at Node_1
#
# Time 344: Frame 68 forwarded from Node_1 to Node_2
# Time 344: Frame 68 spent 0 time units in queue at Node_2
#
# Time 345: Frame 69 created at Node_0, destined for Node_2
# Time 345: Frame 69 spent 0 time units in queue at Node_0
#
# Time 345: Frame 69 forwarded from Node_0 to Node_1
# Time 345: Frame 69 spent 0 time units in queue at Node_1
# Time 348: Frame 68 delivered at Node_2, from Node_0 to Node_2
#
# Time 349: Frame 69 forwarded from Node_1 to Node_2
# Time 349: Frame 69 spent 0 time units in queue at Node_2
#
# Time 350: Frame 70 created at Node_0, destined for Node_2
# Time 350: Frame 70 spent 0 time units in queue at Node_0
#
# Time 350: Frame 70 forwarded from Node_0 to Node_1
# Time 350: Frame 70 spent 0 time units in queue at Node_1
# Time 353: Frame 69 delivered at Node_2, from Node_0 to Node_2
#
# Time 354: Frame 70 forwarded from Node_1 to Node_2
# Time 354: Frame 70 spent 0 time units in queue at Node_2
#
# Time 355: Frame 71 created at Node_0, destined for Node_2
# Time 355: Frame 71 spent 0 time units in queue at Node_0
#
# Time 355: Frame 71 forwarded from Node_0 to Node_1
# Time 355: Frame 71 spent 0 time units in queue at Node_1
# Time 358: Frame 70 delivered at Node_2, from Node_0 to Node_2
#
# Time 359: Frame 71 forwarded from Node_1 to Node_2
# Time 359: Frame 71 spent 0 time units in queue at Node_2
#
# Time 360: Frame 72 created at Node_0, destined for Node_2
# Time 360: Frame 72 spent 0 time units in queue at Node_0
#
# Time 360: Frame 72 forwarded from Node_0 to Node_1
# Time 360: Frame 72 spent 0 time units in queue at Node_1
# Time 363: Frame 71 delivered at Node_2, from Node_0 to Node_2
#
# Time 364: Frame 72 forwarded from Node_1 to Node_2
# Time 364: Frame 72 spent 0 time units in queue at Node_2
#
# Time 365: Frame 73 created at Node_0, destined for Node_2
# Time 365: Frame 73 spent 0 time units in queue at Node_0
#
# Time 365: Frame 73 forwarded from Node_0 to Node_1
# Time 365: Frame 73 spent 0 time units in queue at Node_1
# Time 368: Frame 72 delivered at Node_2, from Node_0 to Node_2
#
# Time 369: Frame 73 forwarded from Node_1 to Node_2
# Time 369: Frame 73 spent 0 time units in queue at Node_2
#
# Time 370: Frame 74 created at Node_0, destined for Node_2
# Time 370: Frame 74 spent 0 time units in queue at Node_0
#
# Time 370: Frame 74 forwarded from Node_0 to Node_1
# Time 370: Frame 74 spent 0 time units in queue at Node_1
# Time 373: Frame 73 delivered at Node_2, from Node_0 to Node_2
#
# Time 374: Frame 74 forwarded from Node_1 to Node_2
# Time 374: Frame 74 spent 0 time units in queue at Node_2
#
# Time 375: Frame 75 created at Node_0, destined for Node_2
# Time 375: Frame 75 spent 0 time units in queue at Node_0
#
# Time 375: Frame 75 forwarded from Node_0 to Node_1
# Time 375: Frame 75 spent 0 time units in queue at Node_1
# Time 378: Frame 74 delivered at Node_2, from Node_0 to Node_2
#
# Time 379: Frame 75 forwarded from Node_1 to Node_2
# Time 379: Frame 75 spent 0 time units in queue at Node_2
#
# Time 380: Frame 76 created at Node_0, destined for Node_2
# Time 380: Frame 76 spent 0 time units in queue at Node_0
#
# Time 380: Frame 76 forwarded from Node_0 to Node_1
# Time 380: Frame 76 spent 0 time units in queue at Node_1
# Time 383: Frame 75 delivered at Node_2, from Node_0 to Node_2
#
# Time 384: Frame 76 forwarded from Node_1 to Node_2
# Time 384: Frame 76 spent 0 time units in queue at Node_2
#
# Time 385: Frame 77 created at Node_0, destined for Node_2
# Time 385: Frame 77 spent 0 time units in queue at Node_0
#
# Time 385: Frame 77 forwarded from Node_0 to Node_1
# Time 385: Frame 77 spent 0 time units in queue at Node_1
# Time 388: Frame 76 delivered at Node_2, from Node_0 to Node_2
#
# Time 389: Frame 77 forwarded from Node_1 to Node_2
# Time 389: Frame 77 spent 0 time units in queue at Node_2
#
# Time 390: Frame 78 created at Node_0, destined for Node_2
# Time 390: Frame 78 spent 0 time units in queue at Node_0
#
# Time 390: Frame 78 forwarded from Node_0 to Node_1
# Time 390: Frame 78 spent 0 time units in queue at Node_1
# Time 393: Frame 77 delivered at Node_2, from Node_0 to Node_2
#
# Time 394: Frame 78 forwarded from Node_1 to Node_2
# Time 394: Frame 78 spent 0 time units in queue at Node_2
#
# Time 395: Frame 79 created at Node_0, destined for Node_2
# Time 395: Frame 79 spent 0 time units in queue at Node_0
# Time 395: Frame 79 discarded at Node_0
# Time 398: Frame 78 delivered at Node_2, from Node_0 to Node_2
#
# Time 400: Frame 80 created at Node_0, destined for Node_2
# Time 400: Frame 80 spent 0 time units in queue at Node_0
#
# Time 400: Frame 80 forwarded from Node_0 to Node_1
# Time 400: Frame 80 spent 0 time units in queue at Node_1
#
# Time 404: Frame 80 forwarded from Node_1 to Node_2
# Time 404: Frame 80 spent 0 time units in queue at Node_2
#
# Time 405: Frame 81 created at Node_0, destined for Node_2
# Time 405: Frame 81 spent 0 time units in queue at Node_0
#
# Time 405: Frame 81 forwarded from Node_0 to Node_1
# Time 405: Frame 81 spent 0 time units in queue at Node_1
# Time 408: Frame 80 delivered at Node_2, from Node_0 to Node_2
#
# Time 409: Frame 81 forwarded from Node_1 to Node_2
# Time 409: Frame 81 spent 0 time units in queue at Node_2
#
# Time 410: Frame 82 created at Node_0, destined for Node_2
# Time 410: Frame 82 spent 0 time units in queue at Node_0
#
# Time 410: Frame 82 forwarded from Node_0 to Node_1
# Time 410: Frame 82 spent 0 time units in queue at Node_1
# Time 413: Frame 81 delivered at Node_2, from Node_0 to Node_2
#
# Time 414: Frame 82 forwarded from Node_1 to Node_2
# Time 414: Frame 82 spent 0 time units in queue at Node_2
#
# Time 415: Frame 83 created at Node_0, destined for Node_2
# Time 415: Frame 83 spent 0 time units in queue at Node_0
#
# Time 415: Frame 83 forwarded from Node_0 to Node_1
# Time 415: Frame 83 spent 0 time units in queue at Node_1
# Time 418: Frame 82 delivered at Node_2, from Node_0 to Node_2
#
# Time 419: Frame 83 forwarded from Node_1 to Node_2
# Time 419: Frame 83 spent 0 time units in queue at Node_2
#
# Time 420: Frame 84 created at Node_0, destined for Node_2
# Time 420: Frame 84 spent 0 time units in queue at Node_0
#
# Time 420: Frame 84 forwarded from Node_0 to Node_1
# Time 420: Frame 84 spent 0 time units in queue at Node_1
# Time 423: Frame 83 delivered at Node_2, from Node_0 to Node_2
#
# Time 424: Frame 84 forwarded from Node_1 to Node_2
# Time 424: Frame 84 spent 0 time units in queue at Node_2
#
# Time 425: Frame 85 created at Node_0, destined for Node_2
# Time 425: Frame 85 spent 0 time units in queue at Node_0
#
# Time 425: Frame 85 forwarded from Node_0 to Node_1
# Time 425: Frame 85 spent 0 time units in queue at Node_1
# Time 428: Frame 84 delivered at Node_2, from Node_0 to Node_2
#
# Time 429: Frame 85 forwarded from Node_1 to Node_2
# Time 429: Frame 85 spent 0 time units in queue at Node_2
#
# Time 430: Frame 86 created at Node_0, destined for Node_2
# Time 430: Frame 86 spent 0 time units in queue at Node_0
#
# Time 430: Frame 86 forwarded from Node_0 to Node_1
# Time 430: Frame 86 spent 0 time units in queue at Node_1
# Time 433: Frame 85 delivered at Node_2, from Node_0 to Node_2
#
# Time 434: Frame 86 forwarded from Node_1 to Node_2
# Time 434: Frame 86 spent 0 time units in queue at Node_2
#
# Time 435: Frame 87 created at Node_0, destined for Node_2
# Time 435: Frame 87 spent 0 time units in queue at Node_0
#
# Time 435: Frame 87 forwarded from Node_0 to Node_1
# Time 435: Frame 87 spent 0 time units in queue at Node_1
# Time 438: Frame 86 delivered at Node_2, from Node_0 to Node_2
#
# Time 439: Frame 87 forwarded from Node_1 to Node_2
# Time 439: Frame 87 spent 0 time units in queue at Node_2
#
# Time 440: Frame 88 created at Node_0, destined for Node_2
# Time 440: Frame 88 spent 0 time units in queue at Node_0
#
# Time 440: Frame 88 forwarded from Node_0 to Node_1
# Time 440: Frame 88 spent 0 time units in queue at Node_1
# Time 443: Frame 87 delivered at Node_2, from Node_0 to Node_2
#
# Time 444: Frame 88 forwarded from Node_1 to Node_2
# Time 444: Frame 88 spent 0 time units in queue at Node_2
#
# Time 445: Frame 89 created at Node_0, destined for Node_2
# Time 445: Frame 89 spent 0 time units in queue at Node_0
#
# Time 445: Frame 89 forwarded from Node_0 to Node_1
# Time 445: Frame 89 spent 0 time units in queue at Node_1
# Time 448: Frame 88 delivered at Node_2, from Node_0 to Node_2
#
# Time 449: Frame 89 forwarded from Node_1 to Node_2
# Time 449: Frame 89 spent 0 time units in queue at Node_2
#
# Time 450: Frame 90 created at Node_0, destined for Node_2
# Time 450: Frame 90 spent 0 time units in queue at Node_0
#
# Time 450: Frame 90 forwarded from Node_0 to Node_1
# Time 450: Frame 90 spent 0 time units in queue at Node_1
# Time 453: Frame 89 delivered at Node_2, from Node_0 to Node_2
#
# Time 454: Frame 90 forwarded from Node_1 to Node_2
# Time 454: Frame 90 spent 0 time units in queue at Node_2
#
# Time 455: Frame 91 created at Node_0, destined for Node_2
# Time 455: Frame 91 spent 0 time units in queue at Node_0
#
# Time 455: Frame 91 forwarded from Node_0 to Node_1
# Time 455: Frame 91 spent 0 time units in queue at Node_1
# Time 458: Frame 90 delivered at Node_2, from Node_0 to Node_2
#
# Time 459: Frame 91 forwarded from Node_1 to Node_2
# Time 459: Frame 91 spent 0 time units in queue at Node_2
#
# Time 460: Frame 92 created at Node_0, destined for Node_2
# Time 460: Frame 92 spent 0 time units in queue at Node_0
#
# Time 460: Frame 92 forwarded from Node_0 to Node_1
# Time 460: Frame 92 spent 0 time units in queue at Node_1
# Time 463: Frame 91 delivered at Node_2, from Node_0 to Node_2
#
# Time 464: Frame 92 forwarded from Node_1 to Node_2
# Time 464: Frame 92 spent 0 time units in queue at Node_2
#
# Time 465: Frame 93 created at Node_0, destined for Node_2
# Time 465: Frame 93 spent 0 time units in queue at Node_0
#
# Time 465: Frame 93 forwarded from Node_0 to Node_1
# Time 465: Frame 93 spent 0 time units in queue at Node_1
# Time 468: Frame 92 delivered at Node_2, from Node_0 to Node_2
#
# Time 469: Frame 93 forwarded from Node_1 to Node_2
# Time 469: Frame 93 spent 0 time units in queue at Node_2
#
# Time 470: Frame 94 created at Node_0, destined for Node_2
# Time 470: Frame 94 spent 0 time units in queue at Node_0
#
# Time 470: Frame 94 forwarded from Node_0 to Node_1
# Time 470: Frame 94 spent 0 time units in queue at Node_1
# Time 473: Frame 93 delivered at Node_2, from Node_0 to Node_2
#
# Time 474: Frame 94 forwarded from Node_1 to Node_2
# Time 474: Frame 94 spent 0 time units in queue at Node_2
#
# Time 475: Frame 95 created at Node_0, destined for Node_2
# Time 475: Frame 95 spent 0 time units in queue at Node_0
#
# Time 475: Frame 95 forwarded from Node_0 to Node_1
# Time 475: Frame 95 spent 0 time units in queue at Node_1
# Time 478: Frame 94 delivered at Node_2, from Node_0 to Node_2
#
# Time 479: Frame 95 forwarded from Node_1 to Node_2
# Time 479: Frame 95 spent 0 time units in queue at Node_2
#
# Time 480: Frame 96 created at Node_0, destined for Node_2
# Time 480: Frame 96 spent 0 time units in queue at Node_0
# Time 480: Frame 96 discarded at Node_0
# Time 483: Frame 95 delivered at Node_2, from Node_0 to Node_2
#
# Time 485: Frame 97 created at Node_0, destined for Node_2
# Time 485: Frame 97 spent 0 time units in queue at Node_0
#
# Time 485: Frame 97 forwarded from Node_0 to Node_1
# Time 485: Frame 97 spent 0 time units in queue at Node_1
#
# Time 489: Frame 97 forwarded from Node_1 to Node_2
# Time 489: Frame 97 spent 0 time units in queue at Node_2
#
# Time 490: Frame 98 created at Node_0, destined for Node_2
# Time 490: Frame 98 spent 0 time units in queue at Node_0
#
# Time 490: Frame 98 forwarded from Node_0 to Node_1
# Time 490: Frame 98 spent 0 time units in queue at Node_1
# Time 493: Frame 97 delivered at Node_2, from Node_0 to Node_2
#
# Time 494: Frame 98 forwarded from Node_1 to Node_2
# Time 494: Frame 98 spent 0 time units in queue at Node_2
#
# Time 495: Frame 99 created at Node_0, destined for Node_2
# Time 495: Frame 99 spent 0 time units in queue at Node_0
# Time 495: Frame 99 discarded at Node_0
# Time 498: Frame 98 delivered at Node_2, from Node_0 to Node_2
#
# Time 500: Frame 100 created at Node_0, destined for Node_2
# Time 500: Frame 100 spent 0 time units in queue at Node_0
#
# Time 500: Frame 100 forwarded from Node_0 to Node_1
# Time 500: Frame 100 spent 0 time units in queue at Node_1
#
# Time 504: Frame 100 forwarded from Node_1 to Node_2
# Time 504: Frame 100 spent 0 time units in queue at Node_2
# Time 508: Frame 100 delivered at Node_2, from Node_0 to Node_2
#
#
# Retrying frame 5, new status: in transit
# Retrying frame 12, new status: in transit
# Retrying frame 16, new status: in transit
# Retrying frame 25, new status: in transit
# Retrying frame 41, new status: in transit
# Retrying frame 47, new status: in transit
# Retrying frame 52, new status: in transit
# Retrying frame 55, new status: in transit
# Retrying frame 63, new status: in transit
# Retrying frame 67, new status: in transit
# Retrying frame 79, new status: in transit
# Retrying frame 96, new status: in transit
# Retrying frame 99, new status: in transit
#
#
# Time 508: Frame 5 spent 0 time units in queue at Node_0
#
# Time 508: Frame 5 forwarded from Node_0 to Node_1
# Time 508: Frame 12 spent 0 time units in queue at Node_0
#
# Time 508: Frame 12 forwarded from Node_0 to Node_1
# Time 508: Frame 16 spent 0 time units in queue at Node_0
# Time 508: Frame 5 spent 0 time units in queue at Node_1
#
# Time 508: Frame 16 forwarded from Node_0 to Node_1
# Time 508: Frame 25 spent 0 time units in queue at Node_0
#
# Time 508: Frame 25 forwarded from Node_0 to Node_1
# Time 508: Frame 41 spent 0 time units in queue at Node_0
#
# Time 508: Frame 41 forwarded from Node_0 to Node_1
# Time 508: Frame 47 spent 0 time units in queue at Node_0
#
# Time 508: Frame 47 forwarded from Node_0 to Node_1
# Time 508: Frame 52 spent 0 time units in queue at Node_0
#
# Time 508: Frame 52 forwarded from Node_0 to Node_1
# Time 508: Frame 55 spent 0 time units in queue at Node_0
#
# Time 508: Frame 55 forwarded from Node_0 to Node_1
# Time 508: Frame 63 spent 0 time units in queue at Node_0
#
# Time 508: Frame 63 forwarded from Node_0 to Node_1
# Time 508: Frame 67 spent 0 time units in queue at Node_0
#
# Time 508: Frame 67 forwarded from Node_0 to Node_1
# Time 508: Frame 79 spent 0 time units in queue at Node_0
#
# Time 508: Frame 79 forwarded from Node_0 to Node_1
# Time 508: Frame 96 spent 0 time units in queue at Node_0
#
# Time 508: Frame 96 forwarded from Node_0 to Node_1
# Time 508: Frame 99 spent 0 time units in queue at Node_0
#
# Time 508: Frame 99 forwarded from Node_0 to Node_1
#
# Time 512: Frame 5 forwarded from Node_1 to Node_2
# Time 512: Frame 12 spent 4 time units in queue at Node_1
# Time 512: Frame 5 spent 0 time units in queue at Node_2
# Time 516: Frame 5 delivered at Node_2, from Node_0 to Node_2
#
# Time 516: Frame 12 forwarded from Node_1 to Node_2
# Time 516: Frame 16 spent 8 time units in queue at Node_1
# Time 516: Frame 12 spent 0 time units in queue at Node_2
# Time 517: Frame 12 delivered at Node_2, from Node_0 to Node_2
#
# Time 520: Frame 16 forwarded from Node_1 to Node_2
# Time 520: Frame 25 spent 12 time units in queue at Node_1
# Time 520: Frame 16 spent 0 time units in queue at Node_2
# Time 521: Frame 16 delivered at Node_2, from Node_0 to Node_2
# Time 524: Frame 25 discarded at Node_1
# Time 524: Frame 41 spent 16 time units in queue at Node_1
# Time 528: Frame 41 discarded at Node_1
# Time 528: Frame 47 spent 20 time units in queue at Node_1
# Time 532: Frame 47 discarded at Node_1
# Time 532: Frame 52 spent 24 time units in queue at Node_1
# Time 536: Frame 52 discarded at Node_1
# Time 536: Frame 55 spent 28 time units in queue at Node_1
# Time 540: Frame 55 discarded at Node_1
# Time 540: Frame 63 spent 32 time units in queue at Node_1
# Time 544: Frame 63 discarded at Node_1
# Time 544: Frame 67 spent 36 time units in queue at Node_1
# Time 548: Frame 67 discarded at Node_1
# Time 548: Frame 79 spent 40 time units in queue at Node_1
# Time 552: Frame 79 discarded at Node_1
# Time 552: Frame 96 spent 44 time units in queue at Node_1
# Time 556: Frame 96 discarded at Node_1
# Time 556: Frame 99 spent 48 time units in queue at Node_1
# Time 560: Frame 99 discarded at Node_1
#
#
# Retrying frame 25, new status: in transit
# Retrying frame 41, new status: in transit
# Retrying frame 47, new status: in transit
# Retrying frame 52, new status: in transit
# Retrying frame 55, new status: in transit
# Retrying frame 63, new status: in transit
# Retrying frame 67, new status: in transit
# Retrying frame 79, new status: in transit
# Retrying frame 96, new status: in transit
# Retrying frame 99, new status: discarded
#
#
# Time 560: Frame 25 spent 0 time units in queue at Node_0
#
# Time 560: Frame 25 forwarded from Node_0 to Node_1
# Time 560: Frame 41 spent 0 time units in queue at Node_0
#
# Time 560: Frame 41 forwarded from Node_0 to Node_1
# Time 560: Frame 47 spent 0 time units in queue at Node_0
# Time 560: Frame 25 spent 0 time units in queue at Node_1
#
# Time 560: Frame 47 forwarded from Node_0 to Node_1
# Time 560: Frame 52 spent 0 time units in queue at Node_0
#
# Time 560: Frame 52 forwarded from Node_0 to Node_1
# Time 560: Frame 55 spent 0 time units in queue at Node_0
#
# Time 560: Frame 55 forwarded from Node_0 to Node_1
# Time 560: Frame 63 spent 0 time units in queue at Node_0
#
# Time 560: Frame 63 forwarded from Node_0 to Node_1
# Time 560: Frame 67 spent 0 time units in queue at Node_0
#
# Time 560: Frame 67 forwarded from Node_0 to Node_1
# Time 560: Frame 79 spent 0 time units in queue at Node_0
#
# Time 560: Frame 79 forwarded from Node_0 to Node_1
# Time 560: Frame 96 spent 0 time units in queue at Node_0
#
# Time 560: Frame 96 forwarded from Node_0 to Node_1
# Time 560: Frame 99 spent 0 time units in queue at Node_0
# Time 560: Frame 99 discarded at Node_0
#
# Time 564: Frame 25 forwarded from Node_1 to Node_2
# Time 564: Frame 41 spent 4 time units in queue at Node_1
# Time 564: Frame 25 spent 0 time units in queue at Node_2
# Time 568: Frame 25 delivered at Node_2, from Node_0 to Node_2
#
# Time 568: Frame 41 forwarded from Node_1 to Node_2
# Time 568: Frame 47 spent 8 time units in queue at Node_1
# Time 568: Frame 41 spent 0 time units in queue at Node_2
# Time 569: Frame 41 delivered at Node_2, from Node_0 to Node_2
#
# Time 572: Frame 47 forwarded from Node_1 to Node_2
# Time 572: Frame 52 spent 12 time units in queue at Node_1
# Time 572: Frame 47 spent 0 time units in queue at Node_2
# Time 573: Frame 47 delivered at Node_2, from Node_0 to Node_2
# Time 576: Frame 52 discarded at Node_1
# Time 576: Frame 55 spent 16 time units in queue at Node_1
# Time 580: Frame 55 discarded at Node_1
# Time 580: Frame 63 spent 20 time units in queue at Node_1
# Time 584: Frame 63 discarded at Node_1
# Time 584: Frame 67 spent 24 time units in queue at Node_1
# Time 588: Frame 67 discarded at Node_1
# Time 588: Frame 79 spent 28 time units in queue at Node_1
# Time 592: Frame 79 discarded at Node_1
# Time 592: Frame 96 spent 32 time units in queue at Node_1
# Time 596: Frame 96 discarded at Node_1
#
#
# Retrying frame 52, new status: in transit
# Retrying frame 55, new status: in transit
# Retrying frame 63, new status: in transit
# Retrying frame 67, new status: in transit
# Retrying frame 79, new status: in transit
# Retrying frame 96, new status: in transit
# Retrying frame 99, new status: in transit
#
#
# Time 596: Frame 52 spent 0 time units in queue at Node_0
#
# Time 596: Frame 52 forwarded from Node_0 to Node_1
# Time 596: Frame 55 spent 0 time units in queue at Node_0
#
# Time 596: Frame 55 forwarded from Node_0 to Node_1
# Time 596: Frame 63 spent 0 time units in queue at Node_0
# Time 596: Frame 52 spent 0 time units in queue at Node_1
#
# Time 596: Frame 63 forwarded from Node_0 to Node_1
# Time 596: Frame 67 spent 0 time units in queue at Node_0
#
# Time 596: Frame 67 forwarded from Node_0 to Node_1
# Time 596: Frame 79 spent 0 time units in queue at Node_0
#
# Time 596: Frame 79 forwarded from Node_0 to Node_1
# Time 596: Frame 96 spent 0 time units in queue at Node_0
#
# Time 596: Frame 96 forwarded from Node_0 to Node_1
# Time 596: Frame 99 spent 0 time units in queue at Node_0
#
# Time 596: Frame 99 forwarded from Node_0 to Node_1
#
# Time 600: Frame 52 forwarded from Node_1 to Node_2
# Time 600: Frame 55 spent 4 time units in queue at Node_1
# Time 600: Frame 52 spent 0 time units in queue at Node_2
# Time 604: Frame 52 delivered at Node_2, from Node_0 to Node_2
#
# Time 604: Frame 55 forwarded from Node_1 to Node_2
# Time 604: Frame 63 spent 8 time units in queue at Node_1
# Time 604: Frame 55 spent 0 time units in queue at Node_2
# Time 605: Frame 55 delivered at Node_2, from Node_0 to Node_2
#
# Time 608: Frame 63 forwarded from Node_1 to Node_2
# Time 608: Frame 67 spent 12 time units in queue at Node_1
# Time 608: Frame 63 spent 0 time units in queue at Node_2
# Time 609: Frame 63 delivered at Node_2, from Node_0 to Node_2
# Time 612: Frame 67 discarded at Node_1
# Time 612: Frame 79 spent 16 time units in queue at Node_1
# Time 616: Frame 79 discarded at Node_1
# Time 616: Frame 96 spent 20 time units in queue at Node_1
# Time 620: Frame 96 discarded at Node_1
# Time 620: Frame 99 spent 24 time units in queue at Node_1
# Time 624: Frame 99 discarded at Node_1
#
#
# Retrying frame 67, new status: in transit
# Retrying frame 79, new status: discarded
# Retrying frame 96, new status: in transit
# Retrying frame 99, new status: in transit
#
#
# Time 624: Frame 67 spent 0 time units in queue at Node_0
#
# Time 624: Frame 67 forwarded from Node_0 to Node_1
# Time 624: Frame 79 spent 0 time units in queue at Node_0
# Time 624: Frame 79 discarded at Node_0
# Time 624: Frame 96 spent 0 time units in queue at Node_0
# Time 624: Frame 67 spent 0 time units in queue at Node_1
#
# Time 624: Frame 96 forwarded from Node_0 to Node_1
# Time 624: Frame 99 spent 0 time units in queue at Node_0
#
# Time 624: Frame 99 forwarded from Node_0 to Node_1
#
# Time 628: Frame 67 forwarded from Node_1 to Node_2
# Time 628: Frame 96 spent 4 time units in queue at Node_1
# Time 628: Frame 67 spent 0 time units in queue at Node_2
# Time 632: Frame 67 delivered at Node_2, from Node_0 to Node_2
#
# Time 632: Frame 96 forwarded from Node_1 to Node_2
# Time 632: Frame 99 spent 8 time units in queue at Node_1
# Time 632: Frame 96 spent 0 time units in queue at Node_2
# Time 633: Frame 96 delivered at Node_2, from Node_0 to Node_2
#
# Time 636: Frame 99 forwarded from Node_1 to Node_2
# Time 636: Frame 99 spent 0 time units in queue at Node_2
# Time 637: Frame 99 delivered at Node_2, from Node_0 to Node_2
#
#
# Retrying frame 79, new status: in transit
#
#
# Time 637: Frame 79 spent 0 time units in queue at Node_0
#
# Time 637: Frame 79 forwarded from Node_0 to Node_1
# Time 637: Frame 79 spent 0 time units in queue at Node_1
#
# Time 641: Frame 79 forwarded from Node_1 to Node_2
# Time 641: Frame 79 spent 0 time units in queue at Node_2
# Time 645: Frame 79 delivered at Node_2, from Node_0 to Node_2
#
# Simulation completed. Packets received: 100, Packets not received: 0
# Retries: 5
# Discarded frames: []
